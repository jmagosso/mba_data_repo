# %% [markdown]
# **Comand **Basics****

# %%
string = 'conteúdo da variável'
print(string)

nome1 = nome2 = nome3 = 'joao'
print(nome1, nome2, nome3)

n, f = 1, 2.0
print(n)
print(f)

#comentário
print(type(f))
print(type(string))

#validando o datatype
print(isinstance(n, int))
print(isinstance(f, str))

# %% [markdown]
# **OPERATORS**

# %%
#resto da divisão
10 % 3

#elevado ao quadrado
10 ** 2

#equação
1 + 8 / 2

#convertendo os valores
i = int('0')
print(isinstance(i, int))


#comparações

# %%
idade  = 10
altura = 1.20

resultado = (idade > 12) and (altura >=1.30)
print(resultado)
