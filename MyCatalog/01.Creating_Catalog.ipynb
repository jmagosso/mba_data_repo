# %%
# Cria um catálogo chamado 'meu_catalogo'
spark.sql("CREATE CATALOG IF NOT EXISTS data_catalog_01_p")

# %%
spark.sql("CREATE CATALOG IF NOT EXISTS data_catalog_01_d")

# %%
# Deleta um catálogo chamado 'meu_catalogo'
spark.sql("DROP CATALOG IF EXISTS data_catalog_01 CASCADE")

# %%
# Depois da criação do catálogo, o próximo nível a ser criado é o schema (database)
spark.sql("CREATE SCHEMA IF NOT EXISTS data_catalog_01_d.bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS data_catalog_01_d.silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS data_catalog_01_d.gold")
# Depois da criação do schema

# %%
# Cria um volume chamado 'vol_data' no schema 'bronze' do catálogo 'data_catalog_01_d'
spark.sql("""
CREATE VOLUME IF NOT EXISTS data_catalog_01_d.bronze.vol_data
""")
