# %%
# %pip install kagglehub

# %%
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("nabeelqureshitiii/student-performance-dataset")
df = pd.read_csv(f"{path}/student_performance.csv")

# %%
df.head()

# %%
#avaliar se existe valores faltantes no nosso dado
df.isna().sum()
df.isnull().sum()

# %% [markdown]
# Analisando as médias das horas de estudo

# %%
df_horas = df[ 'weekly_self_study_hours']
df_horas.head()

# %%
media_horas = df['weekly_self_study_hours'].mean()
media_horas

# %%
media_por_grade = df.groupby('grade')['weekly_self_study_hours'].mean()
media_por_grade

# %%
media_por_grade = df.groupby('grade')['weekly_self_study_hours'].mean()
media_por_grade
